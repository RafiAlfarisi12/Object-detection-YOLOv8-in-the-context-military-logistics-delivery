# %%
# !nvidia-smi
# Out:
# Wed Jan 24 21:42:41 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.65                 Driver Version: 546.65       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 2060      WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   50C    P8               6W /  90W |      0MiB /  6144MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# Testing Video

# %%
from ultralytics import YOLO
model = YOLO("D:\\Data HDD\Data Kuliah Rafi Alfarisi\\Semester 8\\Tugas Akhir\\Final\\YOLOV8\\runs\\detect\\imgs640-epoch500-lr0.001-patience50-new\\weights\\best.pt")
result = model.predict(source="D:\\Data HDD\Data Kuliah Rafi Alfarisi\\Semester 8\\Tugas Akhir\\Final\\YOLOV8\\Testing\\video.mp4", show=True, save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/2827) D:\Data HDD\Data Kuliah Rafi Alfarisi\Semester 8\Tugas Akhir\Final\YOLOV8\Testing\video.mp4: 384x640 1 Car, 9 Humans, 77.6ms
# video 1/1 (2/2827) D:\Data HDD\Data Kuliah Rafi Alfarisi\Semester 8\Tugas Akhir\Final\YOLOV8\Testing\video.mp4: 384x640 1 Car, 8 Humans, 50.8ms
# video 1/1 (3/2827) D:\Data HDD\Data Kuliah Rafi Alfarisi\Semester 8\Tugas Akhir\Final\YOLOV8\Testing\video.mp4: 384x640 1 Car, 7 Humans, 51.0ms
# ...

# %% [markdown]
# Testing Picture

# %%
from ultralytics import YOLO

# Inisialisasi model YOLO
model = YOLO("D:\\Data HDD\\Data Kuliah Rafi Alfarisi\\Semester 8\\Tugas Akhir\\Final\\YOLOV8\\runs\\detect\\imgs640-epoch500-lr0.001-patience50-new\\weights\\best.pt")

# Melakukan prediksi pada gambar
result = model.predict(source="D:\\Data HDD\\Data Kuliah Rafi Alfarisi\\Semester 8\\Tugas Akhir\\Final\\YOLOV8\\Testing\\aircraft.png", show=True, save=True)
# Out:
# image 1/1 D:\Data HDD\Data Kuliah Rafi Alfarisi\Semester 8\Tugas Akhir\Final\YOLOV8\Testing\pict.png: 448x640 4 Humans, 1 Tank, 70.9ms
# Speed: 3.0ms preprocess, 70.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\detect\predict3

# %% [markdown]
# Testing Camera Realtime

# %%
from ultralytics import YOLO
model = YOLO("D:\\Data HDD\Data Kuliah Rafi Alfarisi\\Semester 8\\Tugas Akhir\\Final\\YOLOV8\\runs\\detect\\imgs640-epoch500-lr0.001-patience50-new\\weights\\best.pt")
results = model.predict(source=0 , show = True)
