# %%
# !nvidia-smi
# Out:
# Thu Jan  4 09:27:38 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.33                 Driver Version: 546.33       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 2060      WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   53C    P8              17W /  10W |    869MiB /  6144MiB |     89%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.9.18 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Setup complete ✅ (12 CPUs, 15.8 GB RAM, 521.9/931.5 GB disk)

# %%
from ultralytics import YOLO
 
# Load the model.
model = YOLO('yolov8s.pt')
 
# Training.
results = model.train(
   data='D:\\Data HDD\Data Kuliah Rafi Alfarisi\\Semester 8\\Tugas Akhir\\Final\\YOLOV8\\Dataset\\data.yaml',
   imgsz=640,
   epochs=150,
   lr0=0.001,
   plots=True,
   name='imgs640-epoch150-lr0.001-new'
)
# Out:
# New https://pypi.org/project/ultralytics/8.0.232 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.228 🚀 Python-3.9.18 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...

# %%
from ultralytics import YOLO
 
# Load the model.
model = YOLO('yolov8s.pt')
 
# Training.
results = model.train(
   data='D:\\Data HDD\Data Kuliah Rafi Alfarisi\\Semester 8\\Tugas Akhir\\Final\\YOLOV8\\Dataset\\data.yaml',
   imgsz=640,
   epochs=300,
   lr0=0.001,
   plots=True,
   name='imgs640-epoch300-lr0.001-new'
)
# Out:
# New https://pypi.org/project/ultralytics/8.0.232 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.228 🚀 Python-3.9.18 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...

# %%
from ultralytics import YOLO
 
# Load the model.
model = YOLO('yolov8s.pt')
 
# Training.
results = model.train(
   data='D:\\Data HDD\Data Kuliah Rafi Alfarisi\\Semester 8\\Tugas Akhir\\Final\\YOLOV8\\Dataset\\data.yaml',
   imgsz=640,
   epochs=500,
   lr0=0.001,
   plots=True,
   patience=50,
   name='imgs640-epoch500-lr0.001-patience50-new'
)
# Out:
# Ultralytics YOLOv8.0.234 🚀 Python-3.9.18 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...

# %%
from ultralytics import YOLO
 
# Load the model.
model = YOLO('yolov8s.pt')
 
# Training.
results = model.train(
   data='D:\\Data HDD\Data Kuliah Rafi Alfarisi\\Semester 8\\Tugas Akhir\\Final\\YOLOV8\\Dataset\\data.yaml',
   imgsz=640,
   epochs=150,
   lr0=0.01,
   plots=True,
   name='imgs640-epoch150-lr0.01-new'
)
# Out:
# Ultralytics YOLOv8.0.234 🚀 Python-3.9.18 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...

# %%
from ultralytics import YOLO
 
# Load the model.
model = YOLO('yolov8s.pt')
 
# Training.
results = model.train(
   data='D:\\Data HDD\Data Kuliah Rafi Alfarisi\\Semester 8\\Tugas Akhir\\Final\\YOLOV8\\Dataset\\data.yaml',
   imgsz=640,
   epochs=300,
   lr0=0.01,
   plots=True,
   name='imgs640-epoch300-lr0.01-new'
)
# Out:
# Ultralytics YOLOv8.0.234 🚀 Python-3.9.18 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...

# %%
from ultralytics import YOLO
 
# Load the model.
model = YOLO('yolov8s.pt')
 
# Training.
results = model.train(
   data='D:\\Data HDD\Data Kuliah Rafi Alfarisi\\Semester 8\\Tugas Akhir\\Final\\YOLOV8\\Dataset\\data.yaml',
   imgsz=640,
   epochs=500,
   lr0=0.01,
   plots=True,
   patience=50,
   name='imgs640-epoch500-lr0.01-patience50-new'
)
# Out:
# Ultralytics YOLOv8.0.234 🚀 Python-3.9.18 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...

# %% [markdown]
# perhitungan 2

# %%
from ultralytics import YOLO

model = YOLO("D:\\Data HDD\Data Kuliah Rafi Alfarisi\\Semester 8\\Tugas Akhir\\Final\\YOLOV8\\best.pt")
results = model.predict(source=0 , show = True)
#result = model.predict(source="D:\\Data HDD\Data Kuliah Rafi Alfarisi\\Semester 8\\Tugas Akhir\\Final\\YOLOV8\\test.mp4", show=True)
